# %% [markdown]
# # calculate at a given Temperature

# %%
from ThermoCR.QMthermo import qm_thermo

opt_freq_output_file_path = 'CPD.out'
thermo_result = qm_thermo(atom_coord_path=opt_freq_output_file_path, ee=-194.283781614283, T=298.15, P=101325)
# Out:
# ======= Translation =======
# q_t: 1.2720935150615787e+31
# U_t: 3718.4365201799997
# H_t: 6197.394200299999
# Cv_t: 12.4716972
# Cp_t: 20.786161999999997
# S_t: 161.01710841383226
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ThermoCR.QMthermo import qm_thermo
#       3 opt_freq_output_file_path = 'CPD.out'
# ----> 4 thermo_result = qm_thermo(atom_coord_path=opt_freq_output_file_path, ee=-194.283781614283, T=298.15, P=101325)
#
# File ~\.conda\envs\test_ThermoCR\Lib\site-packages\ThermoCR\QMthermo\qm_thermo.py:122, in qm_thermo(atom_coord_path, atom_numbers, coords, vib_path, vibfreqs, ee_path, ee, T, P, sclZPE, sclU, sclCv, sclS, U_Minenkov, S_Grimme, verbose, read_ee_index, E_list, g_list, ignore_trans_and_rot, c)
#     120     print(f'S_t: {S_t}')
#     121 # rot
# --> 122 q_r, U_r, H_r, Cv_r, Cp_r, S_r = contribution_rot(atom_numbers=atom_numbers, coords=coords, T=T, convert_unit=True)
#     123 if verbose:
#     124     print('========= Rotation ========')
#
# File ~\.conda\envs\test_ThermoCR\Lib\site-packages\ThermoCR\QMthermo\qm_thermo.py:518, in contribution_rot(atom_numbers, coords, T, convert_unit)
#     516         Cv_r = Cv_rot_nonlinear()
#     517         Cp_r = Cp_rot_nonlinear()
# --> 518         S_r = S_rot_nonlinear(q_r=q_r, T=T)
#     519 return q_r, U_r, H_r, Cv_r, Cp_r, S_r
#
# TypeError: S_rot_nonlinear() got an unexpected keyword argument 'T'
