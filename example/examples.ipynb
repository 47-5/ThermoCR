# %% [markdown]
# # calculate at a given Temperature

# %%
from ThermoCR.QMthermo import qm_thermo

opt_freq_output_file_path = 'CPD.out'
thermo_result = qm_thermo(atom_coord_path=opt_freq_output_file_path, ee=-194.283781614283, T=298.15, P=101325)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ThermoCR.QMthermo import qm_thermo
#       3 opt_freq_output_file_path = 'CPD.out'
# ----> 4 thermo_result = qm_thermo(atom_coord_path=opt_freq_output_file_path, ee=-194.283781614283, T=298.15, P=101325)
#
# File ~\.conda\envs\test_ThermoCR\Lib\site-packages\ThermoCR\QMthermo\qm_thermo.py:112, in qm_thermo(atom_coord_path, atom_numbers, coords, vib_path, vibfreqs, ee_path, ee, T, P, sclZPE, sclU, sclCv, sclS, U_Minenkov, S_Grimme, verbose, read_ee_index, E_list, g_list, ignore_trans_and_rot, c)
#     108     g_list = [1]
#     110 # calculate
#     111 # trans
# --> 112 q_t, U_t, H_t, Cv_t, Cp_t, S_t = contribution_trans(M=M, T=T, P=P)
#     113 if verbose:
#     114     print('======= Translation =======')
#
# File ~\.conda\envs\test_ThermoCR\Lib\site-packages\ThermoCR\QMthermo\qm_thermo.py:454, in contribution_trans(M, T, P)
#     452 Cv_t = Cv_trans()
#     453 Cp_t = Cp_trans()
# --> 454 S_t = S_trans(q_t=q_t, T=T)
#     455 return q_t, U_t, H_t, Cv_t, Cp_t, S_t
#
# TypeError: S_trans() got an unexpected keyword argument 'T'
